# %% [markdown]
# <a href="https://colab.research.google.com/github/gilangf03/Tugas-Pertemuan4/blob/main/Tugas_1_Konversi_Grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

#membaca gambar dalam mode grayscale
img = cv2.imread('tomat.jpg' ,cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
plt.title('Citra Asli (Grayscale)')
plt.show()

Binary = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY)[1]
plt.imshow(Binary,cmap= 'gray')
plt.title('citra Binary')
plt.show()

# %%
negative = 255 - img
plt.imshow(negative, cmap='gray')
plt.title('Negative Image')
plt.show()

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

#load the image in color (RGB)
img_rgb= cv2.imread('tomat.jpg')

#convert the RGB image to grayscale
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

#apply logaritmic transformation to the grayscale image
c = 255 / (np.log(1 + np.max(img_gray)))
log_image_gray = c * (np.log(img_gray + 1))
log_image_gray = np.array(log_image_gray, dtype=np.uint8)

plt.imshow(log_image_gray, cmap='gray')
plt.title('Citra Logaritmik (dari Grayscale)')
plt.show()

# %%
gamma = 0.5 # ubah nilai gamma = 0.4, 0.6, 1.2, dst untuk eksperimen
c = 1
power_law = c * np.power(img / 255.0, gamma)
power_law = np.uint8(power_law * 255)

plt.imshow(power_law, cmap='gray')
plt.title(f'Power-law (Gamma={gamma})')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#membaca gambar grayscale
img = cv2.imread('tomat.jpg', cv2.IMREAD_GRAYSCALE)

#definisial kornel (contoh sharpening)
kernel = np.array([[0, -1, 0],
                   [-1, 5, -1],
                  [ 0, -1, 0]])
#operasi konvolusi
conv = cv2.filter2D(img,-1, kernel)

#tampilkan hasil
plt.subplot(1,2,1), plt.imshow(img, cmap='gray'), plt.title('Asli')
plt.subplot(1,2,2), plt.imshow(conv, cmap='gray'), plt.title('Hasil Konvolusi (Sharpen)')
plt.show()
